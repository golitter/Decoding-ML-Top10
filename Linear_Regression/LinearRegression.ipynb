# %% [markdown]
# # 一元线性回归

# %%
import matplotlib.pyplot as plt

# %%
import data_processing_1LR as gd

x, y = gd.get_data()
print(x)
# Out:
# (array([99., 82., 51., ..., 83., 97., 74.]), array([91., 65., 45., ..., 74., 95., 64.]))
# [99. 82. 51. ... 83. 97. 74.]

# %%
plt.scatter(x, y)

# %% [markdown]
# ### 斜率 \( w \) 的公式
# $$ w = \frac{\sum (x_i - \bar{x})(y_i - \bar{y})}{\sum (x_i - \bar{x})^2} $$
#
# ### 截距 \( b \) 的公式
# $$ b = \bar{y} - w \bar{x} $$

# %%
import LinearRegression1 as LR1

w, b = LR1.get_w_b(x, y)
print(w, b)
y_hat = w * x + b
plt.plot(x, y_hat, color='r')
plt.scatter(x, y)
# Out:
# 1.0138367015830543 -15.181799427126307

# %%
# Out:
# 71.4670527796465 45.0
